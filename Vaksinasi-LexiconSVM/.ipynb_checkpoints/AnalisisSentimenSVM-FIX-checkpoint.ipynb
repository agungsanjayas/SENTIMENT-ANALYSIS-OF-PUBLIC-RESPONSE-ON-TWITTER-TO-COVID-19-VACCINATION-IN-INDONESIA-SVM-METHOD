# %%
import csv
import re
import nltk
import Sastrawi
import sklearn
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("dataset\labeled_data.csv")

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
df['tweets'] = df['tweets'].str.lower()

print('Case Folding Result : \n')
print(df['tweets'].head(10))
print('\n\n\n')
# Out:
#                                                  tweets  label  \
# 0     Polres Tanjung Balai Laksanakan Vaksinasi http...    1.0
# 1     Dukung Program Presiden Jokowi 1 Juta Vaksinas...    1.0
# 2     Panglima TNI Marsekal TNI Hadi Tjahjanto menye...    1.0
# 3     Polda Lampung menggelar vaksinasi covid-19 unt...    1.0
# 4     Bupati Kobar Apresiasi Perusahaan Laksanakan V...    1.0
# ...                                                 ...    ...
# 998   Grab Luncurkan Pusat Vaksinasi Ramah Penyandan...    1.0
# 999   Cegah Penyebaran Covid-19, Sentra Vaksinasi Ko...    1.0
# 1000  Seneng liat animo teman-teman makin banyak yan...    1.0
# 1001  Lonjakan Kasus Covid-19 Terjadi, Kemenkes Hany...    0.0
# 1002  @mrs_enci @thedufresne Asa pernah dibahas awal...    1.0
#
#                                            case_folding
# 0     polres tanjung balai laksanakan vaksinasi http...
# 1     dukung program presiden jokowi 1 juta vaksinas...
# 2     panglima tni marsekal tni hadi tjahjanto menye...
# 3     polda lampung menggelar vaksinasi covid-19 unt...
# 4     bupati kobar apresiasi perusahaan laksanakan v...
# ...                                                 ...
# 998   grab luncurkan pusat vaksinasi ramah penyandan...
# 999   cegah penyebaran covid-19, sentra vaksinasi ko...
# 1000  seneng liat animo teman-teman makin banyak yan...
# 1001  lonjakan kasus covid-19 terjadi, kemenkes hany...
# 1002  @mrs_enci @thedufresne asa pernah dibahas awal...
#
# [1003 rows x 3 columns]

# %%
import string 

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_tweet_special(text):
    # Menghapus additional code
    text = text.replace('\\&gt\\&amp', '')
    
    # Menghapus www.* & https?://* 
    text = re.sub(r"https?\://\S+","", text)
    
    # Menghapus mention @
    text = re.sub(r"[@][\w_-]+","", text)
    
    # Menghapus hashtag #
    text = re.sub(r"[#][\w_-]+","", text)
    
    # Menghapus tanda baca
    text = re.sub(r"[^\w\s]"," ", text)
    
    # Menghapus angka
    text = re.sub(r"\d+"," ", text)
    
    # Menghapus spasi ganda
    text = re.sub(r" +"," ", text)
    
    # Menghapus spasi awal
    text = re.sub(r"^\s+","", text)
    
    # Menghapus spasi akhir
    text = re.sub(r"\s+$","",text)

    return text
                
df['tweets'] = df['tweets'].apply(remove_tweet_special)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['tweets'] = df['tweets'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['tweet_tokens'] = df['tweets'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df['tweet_tokens'].head(10))
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0      [polres, tanjung, balai, laksanakan, vaksinasi]
# 1    [dukung, program, presiden, jokowi, juta, vaks...
# 2    [panglima, tni, marsekal, tni, hadi, tjahjanto...
# 3    [polda, lampung, menggelar, vaksinasi, covid, ...
# 4    [bupati, kobar, apresiasi, perusahaan, laksana...
# 5    [rs, columbia, asia, indonesia, mendukung, pro...
# 6    [pengaman, pelaksanaan, vaksinasi, bagi, warga...
# 7    [kabupaten, di, kalbar, disebut, tak, serius, ...
# 8    [salah, banget, vaksinasi, sebelum, ujian, men...
# 9    [silahkan, simak, jadwal, vaksinasi, per, kelu...
# Name: tweet_tokens, dtype: object

# %%
df
# Out:
#                                                  tweets  label  \
# 0             polres tanjung balai laksanakan vaksinasi    1.0
# 1     dukung program presiden jokowi juta vaksinasi ...    1.0
# 2     panglima tni marsekal tni hadi tjahjanto menye...    1.0
# 3     polda lampung menggelar vaksinasi covid untuk ...    1.0
# 4     bupati kobar apresiasi perusahaan laksanakan v...    1.0
# ...                                                 ...    ...
# 998   grab luncurkan pusat vaksinasi ramah penyandan...    1.0
# 999   cegah penyebaran covid sentra vaksinasi kota s...    1.0
# 1000  seneng liat animo teman teman makin banyak yan...    1.0
# 1001  lonjakan kasus covid terjadi kemenkes hanya iz...    0.0
# 1002  asa pernah dibahas awal ya militer diperbantuk...    1.0
#
#                                            tweet_tokens
# 0       [polres, tanjung, balai, laksanakan, vaksinasi]
# 1     [dukung, program, presiden, jokowi, juta, vaks...
# 2     [panglima, tni, marsekal, tni, hadi, tjahjanto...
# 3     [polda, lampung, menggelar, vaksinasi, covid, ...
# 4     [bupati, kobar, apresiasi, perusahaan, laksana...
# ...                                                 ...
# 998   [grab, luncurkan, pusat, vaksinasi, ramah, pen...
# 999   [cegah, penyebaran, covid, sentra, vaksinasi, ...
# 1000  [seneng, liat, animo, teman, teman, makin, ban...
# 1001  [lonjakan, kasus, covid, terjadi, kemenkes, ha...
# 1002  [asa, pernah, dibahas, awal, ya, militer, dipe...
#
# [1003 rows x 3 columns]

# %%
df = df.dropna(axis=0, subset=['label'])
df
# Out:
#                                                  tweets  label  \
# 0             polres tanjung balai laksanakan vaksinasi    1.0
# 1     dukung program presiden jokowi juta vaksinasi ...    1.0
# 2     panglima tni marsekal tni hadi tjahjanto menye...    1.0
# 3     polda lampung menggelar vaksinasi covid untuk ...    1.0
# 4     bupati kobar apresiasi perusahaan laksanakan v...    1.0
# ...                                                 ...    ...
# 998   grab luncurkan pusat vaksinasi ramah penyandan...    1.0
# 999   cegah penyebaran covid sentra vaksinasi kota s...    1.0
# 1000  seneng liat animo teman teman makin banyak yan...    1.0
# 1001  lonjakan kasus covid terjadi kemenkes hanya iz...    0.0
# 1002  asa pernah dibahas awal ya militer diperbantuk...    1.0
#
#                                            tweet_tokens
# 0       [polres, tanjung, balai, laksanakan, vaksinasi]
# 1     [dukung, program, presiden, jokowi, juta, vaks...
# 2     [panglima, tni, marsekal, tni, hadi, tjahjanto...
# 3     [polda, lampung, menggelar, vaksinasi, covid, ...
# 4     [bupati, kobar, apresiasi, perusahaan, laksana...
# ...                                                 ...
# 998   [grab, luncurkan, pusat, vaksinasi, ramah, pen...
# 999   [cegah, penyebaran, covid, sentra, vaksinasi, ...
# 1000  [seneng, liat, animo, teman, teman, makin, ban...
# 1001  [lonjakan, kasus, covid, terjadi, kemenkes, ha...
# 1002  [asa, pernah, dibahas, awal, ya, militer, dipe...
#
# [956 rows x 3 columns]

# %%
df.drop_duplicates(subset=['tweets'], inplace=True)
df
# Out:
#                                                  tweets  label  \
# 0             polres tanjung balai laksanakan vaksinasi    1.0
# 1     dukung program presiden jokowi juta vaksinasi ...    1.0
# 2     panglima tni marsekal tni hadi tjahjanto menye...    1.0
# 3     polda lampung menggelar vaksinasi covid untuk ...    1.0
# 4     bupati kobar apresiasi perusahaan laksanakan v...    1.0
# ...                                                 ...    ...
# 998   grab luncurkan pusat vaksinasi ramah penyandan...    1.0
# 999   cegah penyebaran covid sentra vaksinasi kota s...    1.0
# 1000  seneng liat animo teman teman makin banyak yan...    1.0
# 1001  lonjakan kasus covid terjadi kemenkes hanya iz...    0.0
# 1002  asa pernah dibahas awal ya militer diperbantuk...    1.0
#
#                                            tweet_tokens
# 0       [polres, tanjung, balai, laksanakan, vaksinasi]
# 1     [dukung, program, presiden, jokowi, juta, vaks...
# 2     [panglima, tni, marsekal, tni, hadi, tjahjanto...
# 3     [polda, lampung, menggelar, vaksinasi, covid, ...
# 4     [bupati, kobar, apresiasi, perusahaan, laksana...
# ...                                                 ...
# 998   [grab, luncurkan, pusat, vaksinasi, ramah, pen...
# 999   [cegah, penyebaran, covid, sentra, vaksinasi, ...
# 1000  [seneng, liat, animo, teman, teman, makin, ban...
# 1001  [lonjakan, kasus, covid, terjadi, kemenkes, ha...
# 1002  [asa, pernah, dibahas, awal, ya, militer, dipe...
#
# [792 rows x 3 columns]

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(['ada', 'adalah', 'adlah', 'adlh', 'agak', 'agar', 'agung', 'aja', 'akan', 'anda', 'anu', 'apakah', 'apa', 
                       'april', 'antara', 'atau','amat', 'apalagi', 'angin', 'api', 'akbp', 'azis', 'andriansyah', 's', 'h', 
                       'i', 'k', 'm', 'babhinkamtibmas', 'babinsa', 'bagaimanapun', 'bagi', 'bahwa', 'bandara', 'bandung', 
                       'beberapa', 'bbrp', 'bisa', 'bs', 'begitu', 'boleh', 'bulan', 'bhabinkamtibmas', 'bhabinkantibmas', 
                       'bhayangkara', 'bhayangkari', 'bripka', 'dan', 'dia', 'di', 'dari', 'dalam', 'dlm', 'dengan', 'dgn', 
                       'daripada', 'drpd', 'demi', 'dimana', 'dmn', 'dapat', 'dpt', 'dsb', 'dst', 'dll', 'dahulu', 'dua', 
                       'dulunya', 'demikian', 'desa', 'ds', 'drs', 'digunakan',  'es', 'f', 'februari', 'faceshield', 'gbla', 
                       'gelora', 'gorontalo', 'gue', 'gw', 'gubernur', 'guna', 'hal', 'halo', 'haloo', 'halooo', 'hanya', 
                       'hari', 'harus', 'hujan', 'hi', 'hadi', 'tjahjanto', 'hum', 'ia', 'ini', 'itu', 'itulah', 'ingin', 
                       'jika', 'juga', 'jg', 'jumat', 'jokowi', 'januari', 'juni', 'juli', 'joko', 'kah', 'kabupaten', 'kab', 
                       'kalo', 'klo', 'kapolda', 'kapolri', 'kapolsek', 'kami', 'kamil', 'kamis', 'karena', 'krn', 'kbp', 'ke', 
                       'kecamatan', 'kec', 'kecuali', 'kelurahan', 'kel', 'kemarin', 'kmrn', 'kemenkes', 'kembali', 'kepada', 
                       'kpd', 'kereta', 'ketika', 'kita', 'kenapa', 'knp', 'kemana', 'kan', 'kok', 'kudus', 'lagi', 'lg', 
                       'lain', 'lautan', 'listyo', 'leksono', 'maka', 'maret', 'mari', 'marsekal', 'masih', 'masker', 'menurut', 
                       'msh', 'mereka', 'mrk', 'mengapa', 'melainkan', 'merupakan', 'mei', 'minggu', 'mobilitas', 'namun', 
                       'nanti', 'nggak', 'noh', 'oh', 'oleh', 'ok', 'orang', 'pada', 'pd', 'para', 'pakansari', 'pasti', 
                       'panglima', 'pemkab', 'pemerintah', 'polda', 'polisi', 'polres', 'polri', 'polsek', 'puskesmas', 'pula', 
                       'pmk', 'prabowo', 'presiden', 'rabu', 'rs', 'ridwan', 'saat', 'sabtu', 'sambil', 'sampai', 'satgas', 
                       'saja', 'saya', 'sy', 'sebab', 'sebagai', 'sebelum', 'sblm', 'sebetulnya', 'secara', 'sedangkan', 
                       'seharusnya', 'sehingga', 'sekitar', 'selagi', 'sementara', 'selain', 'seolah', 'seperti', 'seraya', 
                       'serta', 'sesuatu', 'sesudah', 'setelah', 'tadi', 'tapi', 'tp', 'tanpa', 'telah', 'tentang', 'ttg', 
                       'tentu', 'terhadap', 'terminal', 'tetapi', 'tidak', 'toh', 'tolong', 'tni', 'uea', 'untuk', 'utk', 
                       'wakapol', 'wakapolda', 'walau', 'widodo', 'ya', 'yaitu', 'yakni', 'yang', 'yg'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("datasetbismillah\stopwords.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


# remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['tweet_tokens_WSW'] = df['tweet_tokens'].apply(stopwords_removal) 

print('Stopwords Result : \n') 
print(df['tweet_tokens_WSW'].head(10))
print('\n\n\n')
# Out:
# Stopwords Result :
#
# 0              [tanjung, balai, laksanakan, vaksinasi]
# 1    [dukung, program, juta, vaksinasi, lumajang, g...
# 2              [menyebut, lonjakan, covid, terkendali]
# 3    [lampung, menggelar, vaksinasi, covid, anggota...
# 4    [bupati, kobar, apresiasi, perusahaan, laksana...
# 5    [columbia, asia, indonesia, mendukung, program...
# 6    [pengaman, pelaksanaan, vaksinasi, warga, usia...
# 7                  [kalbar, serius, vaksinasi, lansia]
# 8        [salah, banget, vaksinasi, ujian, menangisss]
# 9    [silahkan, simak, jadwal, vaksinasi, ketinggal...
# Name: tweet_tokens_WSW, dtype: object

# %%
df
# Out:
#                                                  tweets  label  \
# 0             polres tanjung balai laksanakan vaksinasi    1.0
# 1     dukung program presiden jokowi juta vaksinasi ...    1.0
# 2     panglima tni marsekal tni hadi tjahjanto menye...    1.0
# 3     polda lampung menggelar vaksinasi covid untuk ...    1.0
# 4     bupati kobar apresiasi perusahaan laksanakan v...    1.0
# ...                                                 ...    ...
# 998   grab luncurkan pusat vaksinasi ramah penyandan...    1.0
# 999   cegah penyebaran covid sentra vaksinasi kota s...    1.0
# 1000  seneng liat animo teman teman makin banyak yan...    1.0
# 1001  lonjakan kasus covid terjadi kemenkes hanya iz...    0.0
# 1002  asa pernah dibahas awal ya militer diperbantuk...    1.0
#
#                                            tweet_tokens  \
# 0       [polres, tanjung, balai, laksanakan, vaksinasi]
# 1     [dukung, program, presiden, jokowi, juta, vaks...
# 2     [panglima, tni, marsekal, tni, hadi, tjahjanto...
# 3     [polda, lampung, menggelar, vaksinasi, covid, ...
# 4     [bupati, kobar, apresiasi, perusahaan, laksana...
# ...                                                 ...
# 998   [grab, luncurkan, pusat, vaksinasi, ramah, pen...
# 999   [cegah, penyebaran, covid, sentra, vaksinasi, ...
# 1000  [seneng, liat, animo, teman, teman, makin, ban...
# 1001  [lonjakan, kasus, covid, terjadi, kemenkes, ha...
# 1002  [asa, pernah, dibahas, awal, ya, militer, dipe...
#
#                                        tweet_tokens_WSW
# 0               [tanjung, balai, laksanakan, vaksinasi]
# 1     [dukung, program, juta, vaksinasi, lumajang, g...
# 2               [menyebut, lonjakan, covid, terkendali]
# 3     [lampung, menggelar, vaksinasi, covid, anggota...
# 4     [bupati, kobar, apresiasi, perusahaan, laksana...
# ...                                                 ...
# 998   [grab, luncurkan, pusat, vaksinasi, ramah, pen...
# 999   [cegah, penyebaran, covid, sentra, vaksinasi, ...
# 1000  [seneng, liat, animo, teman, teman, divaksin, ...
# 1001  [lonjakan, covid, izinkan, vaksin, vaksinasi, ...
# 1002  [dibahas, militer, diperbantukan, vaksinasi, t...
#
# [792 rows x 4 columns]

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['tweet_tokens_WSW']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['tweet_tokens_stemmed'] = df['tweet_tokens_WSW'].swifter.apply(get_stemmed_term)
print(df['tweet_tokens_stemmed'])
# Out:
# 2691
# ------------------------
# tanjung : tanjung
# balai : balai
# laksanakan : laksana
# vaksinasi : vaksinasi
# dukung : dukung
# program : program
# juta : juta
# lumajang : lumajang
# gelar : gelar
# covid : covid
# massal : massal
# menyebut : sebut
# lonjakan : lonjak
# terkendali : kendali
# lampung : lampung
# menggelar : gelar
# anggota : anggota
# keluarga : keluarga
# rumah : rumah
# sakit : sakit
# jalan : jalan
# pramuka : pramuka
# rajabasa : rajabasa
# kota : kota
# bandar : bandar
# bupati : bupati
# kobar : kobar
# apresiasi : apresiasi
# perusahaan : usaha
# gotong : gotong
# royong : royong
# karyawan : karyawan
# columbia : columbia
# asia : asia
# indonesia : indonesia
# mendukung : dukung
# pengaman : kam
# pelaksanaan : laksana
# warga : warga
# usia : usia
# makamhaji : makamhaji
# bertempat : tempat
# brigadir : brigadir
# ruri : ruri
# setiawan : setiawan
# kartasura : kartasura
# koramil : koramil
# melaksanakan : laksana
# pengamanan : aman
# kegiatan : giat
# kalbar : kalbar
# serius : serius
# lansia : lansia
# salah : salah
# banget : banget
# ujian : uji
# menangisss : menangisss
# silahkan : silah
# simak : simak
# jadwal : jadwal
# ketinggalan : tinggal
# kekebalan : kebal
# tubuh : tubuh
# faktor : faktor
# utama : utama
# hadirnya : hadir
# vaksin : vaksin
# mengusir : usir
# corona : corona
# postingan : postingan
# menyebarkan : sebar
# kabar : kabar
# masyarakat : masyarakat
# berdomisili : domisili
# asli : asli
# dki : dki
# jakarta : jakarta
# dibarengi : bareng
# syarat : syarat
# reposted : reposted
# kemayoran : mayor
# gembira : gembira
# sobat : sobat
# sehat : sehat
# provinsi : provinsi
# resmi : resmi
# membuka : buka
# penyelenggaraan : selenggara
# percepatan : cepat
# ditempat : tempat
# interaksinya : interaksi
# stasiun : stasiun
# bus : bus
# airport : airport
# pelabuhan : labuh
# bogor : bogor
# sukses : sukses
# total : total
# pendaftar : daftar
# online : online
# mencapai : capai
# beneran : beneran
# kuliahnya : kuliah
# tatap : tatap
# muka : muka
# ngambil : ngambil
# mk : mk
# ampu : ampu
# tinjau : tinjau
# tekstil : tekstil
# tracing : tracing
# testing : testing
# diperkuat : kuat
# sukun : sukun
# sukseskan : sukses
# selengkapnya : lengkap
# klik : klik
# tautan : taut
# diinisiasi : inisiasi
# pelaku : laku
# usaha : usaha
# kadin : kadin
# bertujuan : tuju
# mempercepat : cepat
# pemberian : beri
# pekerja : kerja
# pengadaan : ada
# sepenuhnya : sepenuh
# dibiayai : biaya
# dibebankan : beban
# berupaya : upaya
# mewujudkan : wujud
# _herd : herd
# immunity_ : immunity
# cepat : cepat
# terlaksananya : laksana
# komunal : komunal
# terbentuk : bentuk
# peningkatan : tingkat
# positif : positif
# ditangani : tangan
# strategi : strategi
# menghadapi : hadap
# pandemi : pandemi
# dosis : dosis
# semoga : moga
# penghuni : huni
# apartemen : apartemen
# gading : gading
# mediterania : mediterania
# jenderal : jenderal
# sigit : sigit
# meninjau : tinjau
# pabrik : pabrik
# sukuntex : sukuntex
# pura : pura
# pertambahan : tambah
# tertinggi : tinggi
# positivity : positivity
# rate : rate
# spesimen : spesimen
# meningkat : tingkat
# menurun : turun
# swab : swab
# test : test
# ditingkatkan : tingkat
# mendekati : dekat
# standar : standar
# who : who
# didampingi : damping
# mentri : tri
# kesehatan : sehat
# direktur : direktur
# kai : kai
# disertai : serta
# sebabkan : sebab
# tenda : tenda
# roboh : roboh
# pemprov : pemprov
# gencarkan : gencar
# midji : midji
# ajak : ajak
# daftarkan : daftar
# harapkan : harap
# keras : keras
# secepat : cepat
# cepatnya : cepat
# target : target
# agustus : agustus
# tercapai : capai
# berharap : harap
# menargetkan : target
# dilanjutkan : lanjut
# membutuhkan : butuh
# rangka : rangka
# herd : herd
# immunity : immunity
# penyebaran : sebar
# hambat : hambat
# peserta : serta
# permata : permata
# jonggol : jonggol
# emc : emc
# sentul : sentul
# bina : bina
# husada : husada
# cimandala : cimandala
# citeureup : citeureup
# karadenan : karadenan
# kesempatan : sempat
# berbincang : bincang
# konferensi : konferensi
# video : video
# perwakilan : wakil
# pkm : pkm
# mengadakan : ada
# sasaran : sasar
# kalangan : kalang
# kaum : kaum
# pendidik : didik
# pedagang : dagang
# pasar : pasar
# tokoh : tokoh
# agama : agama
# pegawai : pegawai
# pelayan : layan
# publik : publik
# difabel : difabel
# transportasi : transportasi
# rentan : rentan
# stadion : stadion
# cibinong : cibinong
# jawa : jawa
# barat : barat
# tersebar : sebar
# khawatir : khawatir
# az : az
# penyakit : sakit
# asma : asma
# ringan : ringan
# jam : jam
# ga : ga
# gejala : gejala
# aman : aman
# pegel : gel
# lengan : lengan
# kiri : kiri
# disuntik : suntik
# lauching : lauching
# gerai : gerai
# upaya : upaya
# ciptakan : cipta
# imunity : imunity
# sumbar : sumbar
# gratis : gratis
# interaksi : interaksi
# besok : besok
# dijadwalkan : jadwal
# makasih : makasih
# membendung : bendung
# penularan : tular
# virus : virus
# berusia : usia
# memprioritaskan : prioritas
# tenaga : tenaga
# kelompok : kelompok
# pendaftarannya : daftar
# yasin : yasin
# dampingi : damping
# tangani : tangan
# percepat : cepat
# perketat : ketat
# ppkm : ppkm
# mikro : mikro
# pilihan : pilih
# percepatkan : cepat
# pilih : pilih
# janji : janji
# gagal : gagal
# penyebab : sebab
# situasi : situasi
# mencekam : cekam
# teror : teror
# vaksinnya : vaksin
# dapatnya : dapat
# jujur : jujur
# hati : hati
# ngasuu : ngasuu
# tunggangi : tunggang
# kpentingan : kpentingan
# rrc : rrc
# genosida : genosida
# terselubung : selubung
# dengar : dengar
# cerita : cerita
# form : form
# diutamakan : utama
# sekolah : sekolah
# dilaksanakan : laksana
# lapangan : lapang
# ahmad : ahmad
# kirang : kirang
# mamuju : mamuju
# disambut : sambut
# antusiasme : antusiasme
# ragu : ragu
# lakukan : laku
# terlindungi : lindung
# daftar : daftar
# vaksinasimu : vaksinasi
# jaki : jaki
# raya : raya
# dokumentasi : dokumentasi
# retail : retail
# modern : modern
# hotel : hotel
# grand : grand
# asrilia : asrilia
# terselenggara : selenggara
# aprindo : aprindo
# bentuk : bentuk
# dukungan : dukung
# denger² : denger
# dave : dave
# duta : duta
# denger : denger
# dicek : cek
# rapid : rapid
# antibodi : antibodi
# hasilnya : hasil
# reaktif : reaktif
# memunculkan : muncul
# melawan : lawan
# pcr : pcr
# antigen : antigen
# pendaftaran : daftar
# tinggal : tinggal
# tahapan : tahap
# keatas : atas
# sebelah : belah
# buka : buka
# analisis : analisis
# evaluasi : evaluasi
# kecenderungan : cenderung
# masyakarat : masyakarat
# jenuh : jenuh
# penerapan : terap
# bp : bp
# tito : tito
# prokes : prokes
# senjata : senjata
# memutus : putus
# rantai : rantai
# disamping : samping
# menciptakan : cipta
# semanan : seman
# rider : rider
# ktp : ktp
# domisili : domisili
# download : download
# aplikasi : aplikasi
# kunjungi : kunjung
# website : website
# pusing : pusing
# kebagian : bagi
# nomer : nomer
# antrian : antri
# yak : yak
# gua : gua
# kelar : kelar
# pasca : pasca
# vaksinasinya : vaksinasi
# kayaknya : kayak
# berlanjut : lanjut
# pala : pala
# pening : pening
# perut : perut
# berasa : asa
# mual : mual
# badan : badan
# keringet : keringet
# dingin : dingin
# parah : parah
# meroket : roket
# lampaui : lampau
# terban : terban
# allah : allah
# pengen : ken
# mencegah : cegah
# bergejala : gejala
# berat : berat
# keterpaparan : papar
# hrusnya : hrusnya
# kebijakan : bijak
# fokus : fokus
# antisipasi : antisipasi
# keterbatasan : batas
# faskes : faskes
# nakes : nakes
# dibayangi : bayang
# ketidakpastian : ketidakpastian
# global : global
# ekonomi : ekonomi
# berpotensi : potensi
# pulih : pulih
# resesi : resesi
# syaratnya : syarat
# pengendalian : kendali
# hartopo : hartopo
# ganjar : ganjar
# pranowo : pranowo
# mendampingi : damping
# menkes : menkes
# ri : ri
# budi : budi
# sadikin : sadikin
# ketua : ketua
# kepala : kepala
# bnpb : bnpb
# letjen : letjen
# ganip : ganip
# warsito : warsito
# tex : tex
# jatah : jatah
# dinkes : dinkes
# pekanbaru : pekanbaru
# batasi : batas
# agnez : agnez
# menyediakan : sedia
# klinik : klinik
# muzdalifah : muzdalifah
# merayakan : raya
# usianya : usia
# terdekat : dekat
# menelan : tel
# uang : uang
# ratusan : ratus
# miliar : miliar
# bingung : bingung
# wacana : wacana
# udh : udh
# progresnya : progres
# hakikatnya : hakikat
# cocok : cocok
# barbarianisme : barbarianisme
# harap : harap
# peran : peran
# aktif : aktif
# sosialisasikan : sosialisasi
# somogede : somogede
# pituruh : pituruh
# menteri : menteri
# pengangkutan : angkut
# wee : wee
# siong : siong
# membantu : bantu
# mempercepatkan : cepat
# sektor : sektor
# melindungi : lindung
# sebel : sebel
# anggep : anggep
# hewan : hewan
# alesan : alesan
# gak : gak
# divaksinasi : vaksinasi
# menurutku : turut
# penyuluhan : suluh
# kususnya : sus
# didaerah : daerah
# terpencil : pencil
# pedesaan : desa
# tujuan : tuju
# sidak : sidak
# inspeksi : inspeksi
# mendadak : dadak
# bae : bae
# klaster : klaster
# mahukan : mahukan
# seramai : serama
# rakyat : rakyat
# kedah : kedah
# terutamanya : utama
# kawasan : kawasan
# sungai : sungai
# petani : tani
# mendaftar : daftar
# yaya : yaya
# paham : paham
# ketersediaan : sedia
# tetep : tetep
# panik : panik
# lonjakannya : lonjak
# god : god
# sake : sake
# jalanan : jalan
# liat : liat
# kuli : kuli
# gapake : gapake
# all : all
# desperate : desperate
# wajibkan : wajib
# ampun : ampun
# masy : masy
# mensosialisasikan : sosialisasi
# digalakan : gala
# olh : olh
# stakeholder : stakeholder
# terkait : kait
# memaksimalkan : maksimal
# mengurangi : kurang
# menekan : tekan
# laju : laju
# wapres : wapres
# pemkot : pemkot
# tangerang : tangerang
# menimbulkan : timbul
# kerumunan : kerumun
# ombudsman : ombudsman
# kepri : kepri
# taknis : taknis
# dikaji : kaji
# ulang : ulang
# melaporkan : lapor
# dokter : dokter
# medis : medis
# tertangkap : tangkap
# sinovac : sinovac
# doctors : doctors
# med : med
# staff : staff
# get : get
# despite : despite
# biddokkes : biddokkes
# tubaba : tubaba
# tekan : tekan
# tau : tau
# info : info
# makasi : makas
# nasional : nasional
# kebanyakan : banyak
# salahnya : salah
# wni : wni
# _ :
# manado : manado
# pulang : pulang
# dilurusin : dilurusin
# dikit : dikit
# acara : acara
# besutan : besut
# ag : ag
# peduli : peduli
# ybs : ybs
# brand : brand
# ambasador : ambasador
# cz : cz
# lokasi : lokasi
# yh : yh
# emang : emang
# geratis : gerat
# badanku : badan
# tumbang : tumbang
# padat : padat
# merayap : rayap
# kerjaan : kerja
# numpuk : numpuk
# kempen : kempen
# anjuran : anjur
# pusat : pusat
# khidmat : khidmat
# parlimen : parlimen
# diteruskan : terus
# menjelajah : jelajah
# kampung : kampung
# bukit : bukit
# sera : sera
# batu : batu
# permohonan : mohon
# dikeluarkan : keluar
# lantaran : lantar
# tersedianya : sedia
# alokasi : alokasi
# simpannya : simpan
# informasi : informasi
# tahap : tahap
# menyusul : susul
# surat : surat
# aspek : aspek
# geospasial : geospasial
# sosial : sosial
# mendaftarkan : daftar
# nama : nama
# keterangan : terang
# membawa : bawa
# memiliki : milik
# kronik : kronik
# kelayakan : layak
# dokte : dokte
# melayani : layan
# rscm : rscm
# pelayanan : layan
# poliklinik : poliklinik
# madya : madya
# lindungi : lindung
# link : link
# fasilitas : fasilitas
# juru : juru
# bicara : bicara
# siti : siti
# nadia : nadia
# tarmizi : tarmizi
# dipungut : pungut
# biaya : biaya
# suntik : suntik
# kementerian : menteri
# izin : izin
# penasaran : penasaran
# umur : umur
# tercapainya : capa
# mengawasi : awas
# jalannya : jalan
# daerah : daerah
# tidur : tidur
# cepet : cepet
# deas : deas
# perhari : hari
# wakil : wakil
# mpr : mpr
# lestari : lestari
# moerdijat : moerdijat
# menilai : nilai
# terbentuknya : bentuk
# direalisasikan : realisasi
# tunjungtejo : tunjungtejo
# rapatkan : rapat
# barisan : baris
# persyaratan : syarat
# layanan : layan
# goshow : goshow
# senin : senin
# jum : jum
# sesuai : sesuai
# sawah : sawah
# halloooo : halloooo
# terupdate : terupdate
# quota : quota
# astrazeneca : astrazeneca
# semarang : semarang
# perbanyak : banyak
# perlindungan : lindung
# terfokus : fokus
# diterapkan : terap
# imunitas : imunitas
# alami : alami
# infeksi : infeksi
# diakui : aku
# berbasis : bas
# risiko : risiko
# proporsional : proporsional
# testostes : testostes
# anggaran : anggar
# mestinya : mesti
# dikurangi : rang
# dialihkan : alih
# insentif : insentif
# sarana : sarana
# prasarana : prasarana
# penelitian : teliti
# teman : teman
# sekitaran : sekitar
# kuningan : kuningan
# setiabudi : setiabudi
# coba : coba
# ambruk : ambruk
# proses : proses
# pindah : pindah
# area : area
# jaga : jaga
# jarak : jarak
# keliar : keliar
# kadus : kadus
# kepulauan : pulau
# sumenep : sumenep
# hut : hut
# tulangbawang : tulangbawang
# pendampingan : damping
# gertak : gertak
# personel : personel
# tembuku : tembuku
# gelombang : gelombang
# perbolehkan : boleh
# terima : terima
# kasih : kasih
# pas : pas
# disuruh : suruh
# minum : minum
# sanmol : sanmol
# malemnya : malemnya
# demam : demam
# pagi : pagi
# turun : turun
# tusukan : tusuk
# bersidang : sidang
# suka : suka
# pm : pm
# dh : dh
# lengkap : lengkap
# dibenarkan : benar
# merentas : rentas
# negeri : negeri
# menghubungi : hubung
# hotline : hotline
# johar : johar
# sahabat : sahabat
# penduduk : duduk
# dipercepat : cepat
# non : non
# depok : depok
# efek : efek
# samping : samping
# dirasakan : rasa
# satunya : satu
# pegal : pegal
# normal : normal
# tanda : tanda
# ladies : ladies
# nganjuk : nganjuk
# ribuan : ribu
# kon : kon
# tha : tha
# pengemudi : kemudi
# bluebird : bluebird
# surabaya : surabaya
# medan : medan
# divaksin : vaksin
# totalnya : total
# ngelakuin : ngelakuin
# mandiri : mandiri
# jabodetabek : jabodetabek
# lombok : lombok
# bali : bal
# perjalananmu : jalan
# meningkatkan : tingkat
# imun : imun
# mudah : mudah
# terjangkit : jangkit
# ketahui : tahu
# menunggu : tunggu
# turn : turn
# imunisasi : imunisasi
# manakah : mana
# valid : valid
# malut : malut
# penerima : terima
# batam : batam
# massa : massa
# diatasi : atas
# contoh : contoh
# putrajaya : putrajaya
# ribu : ribu
# agihan : agih
# tesebut : tesebut
# lengkapkan : lengkap
# jesteru : jesteru
# tutup : tutup
# populasi : populasi
# dilengkapkan : lengkap
# singkat : singkat
# solusi : solusi
# dianggap : anggap
# bermutasi : mutasi
# negara : negara
# terjejas : jejas
# pengagihan : agih
# cadangan : cadang
# pkp : pkp
# malaysia : malaysia
# melengkapkan : lengkap
# saringan : saring
# gelandangan : gelandang
# wpkl : wpkl
# anjung : anjung
# kelana : kelana
# jom : jom
# ambik : ambik
# kebaikan : baik
# belasan : bas
# milik : milik
# bpbd : bpbd
# via : via
# arsel : arsel
# aiptu : aiptu
# nurhadi : nurhadi
# monitoring : monitoring
# aula : aula
# ppk : ppk
# jombang : jombang
# better : better
# stop : stop
# politik : politik
# sekejap : kejap
# ydpa : ydpa
# lantik : lantik
# lead : lead
# selesai : selesai
# anwar : anwar
# tun : tun
# betuk : betuk
# nak : nak
# pulihkan : pulih
# kolam : kolam
# bga : bga
# berdasarkan : dasar
# susah : susah
# sore : sore
# isi : isi
# ditambah : tambah
# kapasitas : kapasitas
# males : males
# targetkan : target
# tuntas : tuntas
# bikin : bikin
# macet : macet
# perkembangan : kembang
# tanggal : tanggal
# wib : wib
# giat : giat
# pam : pam
# wilkum : wilkum
# bangun : bangun
# purba : purba
# selamat : selamat
# siang : siang
# komandan : komandan
# ijin : ijin
# sbb : sbb
# dasar : dasar
# undang : undang
# nomor : nomor
# kepolisian : polisi
# republik : republik
# dashboard : dashboard
# sajikan : saji
# aktual : aktual
# prioritas : prioritas
# politeknik : politeknik
# ati : ati
# makassar : makassar
# kampus : kampus
# berjalan : jalan
# menjamin : jamin
# tersimpan : simpan
# tanah : tanah
# abang : abang
# cegah : cegah
# air : air
# beta : beta
# diterjang : terjang
# badai : badai
# porak : porak
# poranda : poranda
# petugas : tugas
# dievakuasi : evakuasi
# jubir : jubir
# tiongkok : tiongkok
# daratan : darat
# pengaturan : atur
# rekan : rekan
# senegara : negara
# taiwan : taiwan
# tunjukkan : tunjuk
# sayang : sayang
# lingkungannya : lingkung
# lawan : lawan
# masal : masal
# banjar : banjar
# singapadu : singapadu
# kaler : kaler
# abis : abis
# maunya : mau
# senderan : sender
# mulu : mulu
# kaya : kaya
# cakwe : cakwe
# meningkatnya : tingkat
# varian : varian
# mengambil : ambil
# langkah : langkah
# magetan : magetan
# memperingati : ingat
# gedung : gedung
# pesat : pesat
# gatra : gatra
# edisi : edisi
# juanda : juanda
# jalani : jalan
# wilayah : wilayah
# aglomerasi : aglomerasi
# penyangga : sangga
# tingkat : tingkat
# penduduknya : duduk
# sibuk : sibuk
# ngawasin : ngawasin
# personil : personil
# jabiren : jabiren
# amankan : aman
# posyando : posyando
# nusa : nusa
# permisi : permisi
# bu : bu
# daftarnya : daftar
# bpk : bpk
# ruang : ruang
# smbl : smbl
# nunjuk : nunjuk
# verifikasi : verifikasi
# identitas : identitas
# akun : akun
# biar : biar
# centang : centang
# biru : biru
# badmood : badmood
# data : data
# menerima : terima
# persentase : persentase
# persen : persen
# bekasi : bekas
# wujudkan : wujud
# produktif : produktif
# bawa : bawa
# dapet : dapet
# temen : temen
# sudirman : sudirman
# ballroom : ballroom
# cuman : cuman
# sampe : sampe
# skrng : skrng
# admin : admin
# cicalengka : cicalengka
# wetan : wetan
# sekdes : sekdes
# antusias : antusias
# terjang : terjang
# runtuh : runtuh
# tembus : tembus
# harapan : harap
# respon : respon
# dimaklumi : maklum
# komentar : komentar
# tenggelam : tenggelam
# netizen : netizen
# mayoritas : mayoritas
# percaya : percaya
# bahaya : bahaya
# miris : miris
# kolom : kolom
# sukabumi : sukabumi
# mengunjungi : unjung
# situs : situs
# titik : titik
# xl : xl
# axiata : axiata
# tbk : tbk
# bertahap : tahap
# kesehtan : kesehtan
# gunadi : gunadi
# bdg : bdg
# pos : pos
# dilimit : limit
# either : either
# pntg : pntg
# diusahain : diusahain
# shoot : shoot
# memudahkan : mudah
# ckup : ckup
# overdosis : overdosis
# disosialisasiin : disosialisasiin
# jalur : jalur
# nambo : nambo
# jumpa : jumpa
# diadakan : ada
# komunitas : komunitas
# terbatas : batas
# undangan : undang
# commuter : commuter
# kci : kci
# pengguna : guna
# krl : krl
# informasinya : informasi
# panmas : panmas
# bayangkari : bayangkari
# keseeel : keseeel
# napsu : napsu
# makan : makan
# hilang : hilang
# mulutpun : mulut
# menolak : tolak
# mengunyah : kunyah
# kapolres : kapolres
# metro : metro
# selatan : selatan
# menghadiri : hadir
# rapat : rapat
# dikantor : kantor
# walikota : walikota
# gampang : gampang
# web : web
# seputar : putar
# liatnya : liat
# satuan : satu
# brimob : brimob
# pidie : pidie
# tracking : tracking
# zona : zona
# merah : merah
# pengusaha : usaha
# programkan : program
# sehari : hari
# grab : grab
# hadirkan : hadir
# ramah : ramah
# penyandang : sandang
# disabilitas : disabilitas
# yogyakarta : yogyakarta
# muda : muda
# karna : karna
# risikonya : risiko
# tua : tua
# ngeri : ngeri
# ngebludak : ngebludak
# spot : spot
# dluan : dluan
# alasan : alas
# tunggu : tunggu
# adaaaa : adaaaa
# milih : milih
# jasa : jasa
# keuangan : uang
# digelar : gelar
# tennis : tennis
# indoor : indoor
# senayan : senayan
# tts : tts
# kondisi : kondisi
# langka : langka
# mengakibatkan : akibat
# trombositopenia : trombositopenia
# lampu : lampu
# perburukan : buru
# kematian : mati
# hinga : hinga
# menghindari : hindar
# mengkhawatirkan : khawatir
# selaras : selaras
# rekomendasi : rekomendasi
# papdi : papdi
# penggunaan : guna
# pedoman : pedoman
# diagnosis : diagnosis
# tatalaksana : tatalaksana
# sindrom : sindrom
# trombosis : trombosis
# vektor : vektor
# adenovirus : adenovirus
# diharapkan : harap
# penderita : derita
# perawatan : awat
# tataran : tatar
# tangga : tangga
# angka : angka
# metode : metode
# azd : azd
# berjenis : jenis
# viral : viral
# berbeda : beda
# jenis : jenis
# teraktivitas : aktivitas
# dimatikan : mati
# menanjak : tanjak
# pelbagai : pelbagai
# belahan : bahan
# dunia : dunia
# munculnya : muncul
# menular : tular
# diupayakan : upaya
# sumsel : sumsel
# brigjen : brigjen
# rudi : rudi
# rivai : rivai
# abdullah : abdullah
# kundur : kundur
# mariana : mariana
# banyuasin : banyuasin
# batubulan : batubulan
# lingkungan : lingkung
# bbws : bbws
# serayu : rayu
# opak : opak
# puluhan : puluh
# pkl : pkl
# ppp : ppp
# mayangan : mayang
# gini : gin
# yb : yb
# mlati : mlati
# sendangadi : sendangadi
# serka : serka
# nuralim : nuralim
# pendopo : pendopo
# kalurahan : kalurahan
# kapanewon : kapanewon
# mulia : mulia
# ayolah : ayo
# guru : guru
# pringsewu : pringsewu
# ketiga : tiga
# rampung : rampung
# menangani : tangan
# susahnya : susah
# drive : drive
# thru : thru
# motor : motor
# nyediain : nyediain
# parkir : parkir
# plis : plis
# atur : atur
# segambreng : segambreng
# gambreng : gambreng
# ojek : ojek
# malang : malang
# bunda : bunda
# kopda : kopda
# ngembatpadas : ngembatpadas
# wakapolsek : wakapolsek
# iptu : iptu
# sucipto : sucipto
# pemantauan : pantau
# jatibatur : jatibatur
# gemolong : golong
# keberanian : berani
# menenangkan : tenang
# saraf : saraf
# bang : bang
# rencana : rencana
# ntb : ntb
# bergantung : gantung
# buatan : buat
# lokal : lokal
# rorotan : rorotan
# dinamis : dinamis
# mengikuti : ikut
# wali : wali
# bima : bima
# arya : arya
# didiek : didiek
# hartantyo : hartantyo
# keterangannya : terang
# selepas : lepas
# sta : sta
# insya : insya
# memvaksin : vaksin
# dewasa : dewasa
# tuan : tuan
# luncurkan : luncur
# spare : spare
# part : part
# jambi : jambi
# sasar : sasar
# serentak : serentak
# indramayu : indramayu
# olimpiade : olimpiade
# mending : mending
# diundur : undur
# dibatalin : dibatalin
# sistem : sistem
# jepang : jepang
# aneh : aneh
# semaju : maju
# nentang : nentang
# nyentuh : nyentuh
# gila : gila
# dipindah : pindah
# ruangan : ruang
# australia : australia
# memperbolehkan : boleh
# pancoran : pancoran
# sentra : sentra
# sma : sma
# perguruan : guru
# cikini : cikini
# gor : gor
# pengadegan : adegan
# smesco : smesco
# tulungagung : tulungagung
# handono : handono
# subiakto : subiakto
# mh : mh
# cabang : cabang
# pns : pns
# purna : purna
# warakawuri : warakawuri
# medsos : medsos
# penyelenggara : selenggara
# mahasiswa : mahasiswa
# pra : pra
# korban : korban
# phk : phk
# pengangguran : anggur
# check : check
# out : out
# great : great
# kadiskes : kadiskes
# riau : riau
# pastikan : pasti
# inhu : inhu
# rohul : rohul
# meninggal : tinggal
# kunjungan : kunjung
# peninjauan : tinjau
# lanumad : lanumad
# yani : yani
# asistensi : asistensi
# barutama : barutama
# bpjs : bpjs
# tanggung : tanggung
# akibat : akibat
# faktanya : fakta
# jajaran : jajar
# lembaga : lembaga
# pemasyarakatan : masyarakat
# kelas : kelas
# iia : iia
# bulukumba : bulukumba
# smp : smp
# mampir : mampir
# dilapak : lapak
# habisnya : habis
# bareng : bareng
# terwujud : wujud
# mantap : mantap
# ayo : ayo
# takut : takut
# tujuannya : tuju
# spesifik : spesifik
# terpaksa : paksa
# hiyaa : hiyaa
# smk : smk
# nurul : nurul
# islam : islam
# cianjur : cianjur
# penyembuhan : sembuh
# showbiz : showbiz
# bahbinkamtibmas : bahbinkamtibmas
# tahai : tahai
# jaya : jaya
# tumbuhkan : tumbuh
# kesadaran : sadar
# denmark : denmark
# aturan : atur
# pake : pake
# dicabut : cabut
# ttp : ttp
# musti : musti
# seminggu : minggu
# suami : suami
# tmpt : tmpt
# kerjanya : kerja
# giliran : gilir
# skr : skr
# kelahiran : lahir
# dikonsentrasi : konsentrasi
# goblog : goblog
# oke : oke
# sekelurahan : lurah
# dipecah : pecah
# deras : deras
# datangi : datang
# mbak : mbak
# slot : slot
# rsud : rsud
# keb : keb
# ikutin : ikutin
# ssnya : ssnya
# capaian : capai
# cakupan : cakup
# kalimantan : kalimantan
# terbilang : bilang
# rendah : rendah
# capaiannya : capai
# pencegahan : cegah
# bale : bale
# wonosigro : wonosigro
# supermarket : supermarket
# indomaret : indomaret
# alfamart : alfamart
# legenda : legenda
# malaka : malaka
# kehabisan : habis
# youc : youc
# botol : botol
# kaca : kaca
# adakan : adakan
# temenggung : temenggung
# mega : mega
# mall : mall
# untung : untung
# nemu : nemu
# toko : toko
# klontong : klontong
# nusantara : nusantara
# kalahkan : kalah
# delta : delta
# terawan : awan
# forkopimda : forkopimda
# terhenti : henti
# foto : foto
# ar : ar
# menduran : mendur
# brati : brati
# nasi : nasi
# kapau : kapau
# jangkau : jangkau
# pulau : pulau
# tanjungpinang : tanjungpinang
# penyengat : sengat
# bedakan : beda
# ketahap : tahap
# memantau : pantau
# nuhun : nuhun
# bojongkulur : bojongkulur
# digiatkan : giat
# mengendalikan : kendali
# catatan : catat
# dinas : dinas
# ciangsana : ciangsana
# wilujeng : wilujeng
# wengi : wengi
# wargi : wargi
# belom : bom
# itb : itb
# bru : bru
# kmaren : kmaren
# gatau : gatau
# pisah : pisah
# kk : kk
# keitung : keitung
# ngga : ngga
# udara : udara
# darat : darat
# laut : laut
# disetuju : tuju
# bahawa : bahawa
# terbang : terbang
# depoh : depoh
# industri : industri
# konyol : konyol
# dibilang : bilang
# dibikin : bikin
# kontinue : kontinue
# seabrek : abrek
# singgah : singgah
# bengkayang : bengkayang
# khofifah : khofifah
# alat : alat
# ngeluh : ngeluh
# netijen : netijen
# ngomong : ngomong
# resiko : resiko
# suruh : suruh
# bhaiiiiiqqqqq : bhaiiiiiqqqqq
# apapun : apa
# subjek : subjek
# joyokusumo : joyokusumo
# persyaratannya : syarat
# pakai : pakai
# barusan : barusan
# pati : pati
# ojk : ojk
# kementrian : tri
# forkopimcam : forkopimcam
# pasekan : pasekan
# gencar : gencar
# this : this
# one : one
# too : too
# bahan : bahan
# pengetahuan : tahu
# mutasi : mutasi
# sebar : sebar
# berita : berita
# propaganda : propaganda
# pengetahuannya : tahu
# terkhusus : khusus
# minn : minn
# terjadwal : jadwal
# submit : submit
# thx : thx
# advance : advance
# kepatuhan : patuh
# warganya : warga
# memakai : pakai
# diimbau : imbau
# lengah : lengah
# nunda : nunda
# rumkitlap : rumkitlap
# ancol : ancol
# mal : mal
# artha : artha
# palipi : palipi
# herman : herman
# siahaan : siahaan
# sitio : sitio
# tio : tio
# maria : maria
# samosir : samosir
# cek : cek
# mobilitasnya : mobilitas
# situlah : situ
# segerakan : segera
# kadrun : kadrun
# panglimanya : panglima
# berbondong : bondong
# bondong : bondong
# gebyar : gebyar
# sirnarasa : sirnarasa
# infodesaku : infodesaku
# suntikan : sunti
# pencanganan : pencanganan
# day : day
# struggle : struggle
# diy : diy
# pekan : pekan
# pergunakan : guna
# menjaga : jaga
# pengalaman : alam
# cemput : cemput
# ambil : ambil
# antri : antri
# screaning : screaning
# tmmd : tmmd
# kodim : kodim
# ternate : ternate
# pantau : pantau
# moti : moti
# ajibarang : ajibarang
# jemput : jemput
# optimalkan : optimal
# minbeks : minbeks
# jiwa : jiwa
# insiden : insiden
# robohnya : roboh
# stadiun : stadiun
# wako : wako
# padang : padang
# perumda : perumda
# dorong : dorong
# depresi : depresi
# ngelihat : ngelihat
# baca : baca
# dikasih : kasih
# media : media
# omongnya : omong
# diem : diem
# kasian : kasi
# hidup : hidup
# gedebage : gedebage
# polrestabes : polrestabes
# serbuan : serbu
# rancanumpang : rancanumpang
# menerapkan : terap
# protokol : protokol
# hadiri : hadir
# artis : artis
# hijrah : hijrah
# baiknya : baik
# orang² : orang
# sentral : sentral
# versi : versi
# mini : mini
# butuh : butuh
# koordinasi : koordinasi
# textile : textile
# diperketat : ketat
# jayanti : jayanti
# palabuhanratu : palabuhanratu
# sukabumj : sukabumj
# bansos : bansos
# blt : blt
# dd : dd
# boyolali : boyolali
# randusari : randusari
# teras : teras
# solusinya : solusi
# nganggur : nganggur
# beternak : ternak
# sapi : sapi
# kambing : kambing
# unggas : unggas
# rapp : rapp
# kuansing : kuansing
# datangkan : datang
# sinopharm : sinopharm
# ws : ws
# mahasiswi : mahasiswi
# stay : stay
# nanya : nanya
# beraktivitas : aktivitas
# sob : sob
# engga : engga
# kerabat : kerabat
# mengalami : alami
# kejadian : jadi
# ikutan : ikut
# kipi : kipi
# tenang : tenang
# sobatkom : sobatkom
# sensasi : sensasi
# buru : buru
# buruan : buru
# hoki : hoki
# hokian : hoki
# serasa : serasa
# heboh : heboh
# hebohan : heboh
# ngisi : ngisi
# krs : krs
# akang : akang
# ad : ad
# secapa : capa
# hegarmanah : hegarmanah
# dipimpin : pimpin
# wakapolres : wakapolres
# tribrata : tribrata
# dibawah : bawah
# taun : taun
# muspika : muspika
# kemalang : malang
# pengecekan : kece
# gel : gel
# kantor : kantor
# tlogowatu : tlogowatu
# klaten : klaten
# only : only
# way : way
# back : back
# takde : takde
# patroli : patroli
# sambung : sambung
# pemdes : pemdes
# bojong : bojong
# kawunganten : kawunganten
# woro : woro
# himbauan : himbauan
# kamtibmas : kamtibmas
# patuhi : patuh
# terapkan : terap
# srt : srt
# kerawanan : rawan
# rais : rais
# syuriyah : syuriyah
# pcnu : pcnu
# ikhtiar : ikhtiar
# kolektif : kolektif
# atasi : atas
# senior : senior
# rutan : rutan
# binaan : bina
# subsie : subsie
# administrasi : administrasi
# gaffar : gaffar
# waliyondi : waliyondi
# yusman : yusman
# sosialisasi : sosialisasi
# berminat : minat
# dok : dok
# berburu : buru
# cari : cari
# rawan : rawan
# gtu : gtu
# wonoroto : wonoroto
# kanit : kanit
# intel : intel
# widasari : widasari
# bangodua : bangodua
# kependidikan : didik
# diwilayah : wilayah
# bocah : bocah
# digigit : gigit
# anjing : anjing
# rabies : rabies
# id : id
# denpasar : denpasar
# capai : capai
# gibran : gibran
# optimis : optimis
# solo : solo
# dirilis : rilis
# swalayan : swalayan
# gardena : gardena
# urip : urip
# sumoharjo : sumoharjo
# sabhara : sabhara
# gondokusuman : gondokusuman
# panit : panit
# ipda : ipda
# wagimin : wagimin
# sambang : sambang
# dibuka : buka
# pdpr : pdpr
# seruan : seru
# serda : serda
# suroto : suroto
# adik : adik
# kandung : kandung
# konsultasi : konsultasi
# terkontrol : kontrol
# istri : istri
# menyusui : susu
# stlh : stlh
# konsultasikan : konsultasi
# biarkan : biar
# bodo : bodo
# reg : reg
# feb : feb
# tiba² : tiba
# phase : phase
# lembab : lembab
# sgt : sgt
# ppv : ppv
# parking : parking
# nam : nam
# diterpa : terpa
# kencang : kencang
# eksekutif : eksekutif
# kumpulan : kumpul
# msm : msm
# holdings : holdings
# bhd : bhd
# syed : syed
# feizal : feizal
# mohammad : mohammad
# permintaan : minta
# gula : gula
# halus : halus
# seiring : iring
# serasan : ras
# perempuan : perempuan
# rajawali : rajawali
# berbakti : bakti
# bangsanya : bangsa
# sumbangsihnya : sumbangsih
# membangun : bangun
# kenal : kenal
# kmarin : kmarin
# batch : batch
# puji : puji
# tuhan : tuhan
# screening : screening
# jadwalnya : jadwal
# deket : deket
# dibolehin : dibolehin
# petugasnya : tugas
# daun : daun
# capek : capek
# hrs : hrs
# psbb : psbb
# ketat : ketat
# cipinang : cipinang
# korsel : korsel
# farmasi : farmasi
# keamanan : aman
# siber : siber
# berdampak : dampak
# blog : blog
# setia : setia
# korem : korem
# abw : abw
# fasilitasi : fasilitas
# interen : interen
# budayakan : budaya
# marut : marut
# kelapa : kelapa
# pemko : pemko
# payakumbuh : payakumbuh
# jakpus : jakpus
# blok : blok
# seribu : ribu
# genjot : genjot
# driver : driver
# ojol : ojol
# beroperasi : operasi
# kebadan : bad
# gandeng : gandeng
# bertemu : temu
# vial : vial
# ditargetkan : target
# terpakai : pakai
# pemerintahan : perintah
# adk : adk
# adian : adi
# koting : koting
# sinergitas : sinergitas
# kawal : kawal
# endless : endless
# jalankan : jalan
# manapun : mana
# tingkatkan : tingkat
# disiplin : disiplin
# ingatkan : ingat
# putuskan : putus
# terlepas : lepas
# drama : drama
# eldorado : eldorado
# sabi : sabi
# dibanding : banding
# perhatian : perhati
# lebat : lebat
# butiran : butir
# menyebabkan : sebab
# tpp : tpp
# kendari : kendari
# terancam : ancam
# dipotong : potong
# diam : diam
# tuai : tuai
# decak : decak
# kagum : kagum
# idola : idola
# tiket : tiket
# pedulilindungi : pedulilindungi
# tulisannya : tulis
# bener : bener
# kehadiran : hadir
# grogol : grogol
# mengedukasi : edukasi
# pemberlakukan : laku
# pembatasan : batas
# berskala : skala
# penanganan : tangan
# alamak : alamak
# jang : jang
# londo : londo
# austria : austria
# anak : anak
# wedok : wedok
# mbarep : mbarep
# titip : titip
# sptw : sptw
# parkiran : parkir
# mensukseskan : sukses
# senggigi : senggigi
# bebas : bebas
# ketatkan : ketat
# abaikan : abai
# kapuas : kapuas
# danau : danau
# mare : mare
# banda : banda
# aceh : aceh
# wtckl : wtckl
# kuala : kuala
# lumpur : lumpur
# persekutuan : sekutu
# diskominfo : diskominfo
# persediaan : sedia
# benowo : benowo
# pilar : pilar
# sememi : mem
# dos : dos
# baki : baki
# imuniti : imuniti
# st : st
# nd : nd
# jangkaan : jangka
# bilangan : bilang
# menyambut : sambut
# toba : toba
# berkunjung : kunjung
# tim : tim
# komisi : komisi
# ix : ix
# dpr : dpr
# diakses : akses
# kuota : kuota
# sing : sing
# wegah : wegah
# rung : rung
# gelem : gelem
# rasah : rasah
# ngojok : ngojok
# ngojoki : ngojoki
# sakjane : sakjane
# panitia : panitia
# pilkades : pilkades
# purwakarta : purwakarta
# gaada : gaada
# muncul : muncul
# cluster : cluster
# jaman : jaman
# komando : komando
# hadir : hadir
# mengoptimalkan : optimal
# kinerja : kerja
# insan : insan
# hulu : hulu
# migas : migas
# kedepannya : depan
# menjalankan : jalan
# tugas : tugas
# pengawasan : awas
# minyak : minyak
# gas : gas
# bumi : bumi
# cita : cita
# jt : jt
# jabar : jabar
# kartu : kartu
# alamatnya : alamat
# beda : beda
# dilakukannya : laku
# skk : skk
# sumbagsel : sumbagsel
# mewakili : wakil
# anggono : anggono
# mahendrawan : mahendrawan
# departemen : departemen
# humas : humas
# andi : andi
# arie : arie
# ucapan : ucap
# peratus : atus
# wajar : wajar
# teknikal : teknikal
# biadap : biadap
# cuba : cuba
# menidakkan : tidak
# titah : titah
# rrm : rrm
# dilanda : landa
# ahli : ahli
# tdi : tdi
# gbl : gbl
# ku : ku
# hhmmm : hhmmm
# teu : teu
# narima : narima
# kitu : kitu
# sarehat : sarehat
# deui : deui
# daya : daya
# tahan : tahan
# ayeuna : ayeuna
# keur : keur
# panca : panca
# roba : roba
# gelaran : gelar
# berjudul : judul
# rencananya : rencana
# diikuti : ikut
# masyarakatnya : masyarakat
# urkes : urkes
# probolinggo : probolinggo
# bergerak : gerak
# tarik : tarik
# rem : rem
# lambat : lambat
# ngegas : ngegas
# jancuk : jancuk
# diprioritaskan : prioritas
# faskesnya : faskesnya
# irit : irit
# mumpung : mumpung
# manfaatkan : manfaat
# sintong : sintong
# abadi : abadi
# tirtohargo : tirtohargo
# pantauan : pantau
# biro : biro
# pers : pers
# sekretariat : sekretariat
# youtube : youtube
# serma : serma
# suripan : suripan
# peleman : lem
# sugiyanto : sugiyanto
# harian : hari
# diinfokan : info
# menurunkan : turun
# perkantoran : kantor
# buanajaya : buanajaya
# ubrug : ubrug
# bantargadung : bantargadung
# puskesma : puskesma
# warungkiara : warungkiara
# ditunda : tunda
# badung : badung
# abiansemal : abiansemal
# pemenuhan : penuh
# forum : forum
# pimpinan : pimpin
# forkopimko : forkopimko
# seandainya : anda
# dikemas : kemas
# tablet : tablet
# sachet : sachet
# nandi : nandi
# sukaharja : sukaharja
# membaca : baca
# memperbaharui : baharu
# penanggulangan : tanggulang
# alumni : alumni
# keluarganya : keluarga
# lokasinya : lokasi
# jakbar : jakbar
# dandim : dandim
# rusun : rusun
# angke : angke
# tambora : tambora
# kecolongan : colong
# kontak : kontak
# apd : apd
# uji : uji
# klinis : klinis
# kolaborasi : kolaborasi
# green : green
# izinkan : izin
# cikarang : cikarang
# timur : timur
# kepalaku : kepala
# mimpi : mimpi
# buruk : buruk
# sporadis : sporadis
# minimal : minimal
# parebut : parebut
# padedet : padedet
# pasongsongan : pasongsongan
# kebutuhan : butuh
# ut : ut
# menyerbu : serbu
# beredar : edar
# antrean : antre
# mengisi : isi
# memilih : pilih
# libatkan : libat
# welcome : welcome
# infonya : info
# skemanya : skema
# menyumbangkan : sumbang
# karyawannya : karyawannya
# msyarakat : msyarakat
# kalteng : kalteng
# tambahan : tambah
# optimal : optimal
# gamau : gamau
# sebenernya : sebenernya
# berhubung : hubung
# dianjurin : dianjurin
# kradinan : kradinan
# dirasa : rasa
# sus : sus
# ngantuk : ngantuk
# laper : laper
# laperan : laperan
# ketawa : ketawa
# wagub : wagub
# terbaru : baru
# pkk : pkk
# bitung : bitung
# prakarsai : prakarsa
# memadati : padat
# kompleks : kompleks
# barus : barus
# hendra : hendra
# sinaga : sinaga
# memonitor : monitor
# memasuki : pasuk
# kedung : kedung
# waringin : waringin
# gianto : gianto
# koordinasikan : koordinasi
# diatas : atas
# menyapa : sapa
# andrei : andrei
# angouw : angouw
# detail : detail
# center : center
# sanksinya : sanksi
# richard : richard
# sualang : sualang
# hebat : hebat
# mudik : mudik
# mutusin : mutusin
# ndak : ndak
# sertu : sertu
# sutardi : sutardi
# genengduwur : genengduwur
# irjen : irjen
# asep : asep
# suhendar : suhendar
# royal : royal
# ambarukmo : ambarukmo
# cikarageman : cikarageman
# aipda : aipda
# ugi : ugi
# handoko : handoko
# setu : setu
# never : never
# idea : idea
# supriyanta : supriyanta
# matroni : matroni
# kp : kp
# bulak : bulak
# bunut : bunut
# karangsambung : karangsambung
# dongkrak : dongkrak
# gairah : gairah
# nu : nu
# mpd : mpd
# relawan : rawan
# pembayarannya : bayar
# mrupakn : mrupakn
# kemekes : kemekes
# prcepatan : prcepatan
# memerhatikan : perhati
# diperjualbelikan : diperjualbelikan
# mengatur : atur
# pengobatan : obat
# indikasi : indikasi
# mengizinkan : izin
# merek : merek
# skema : skema
# hibah : hibah
# ditetapkan : tetap
# gr : gr
# moderna : moderna
# cansino : cansino
# pfizer : pfizer
# novavax : novavax
# mantau : mantau
# face : face
# shield : shield
# sok : sok
# ko : ko
# nyontohinnya : nyontohinnya
# kasar : kasar
# diterjunkan : terjun
# pelatihan : latih
# vaksinator : vaksinator
# pemda : pemda
# cengkareng : cengkareng
# show : show
# rahmadi : rahmadi
# danramil : danramil
# tanon : tanon
# tribunnews : tribunnews
# dapatkan : dapat
# android : android
# merata : rata
# sya : sya
# pemerintahnya : perintah
# kpda : kpda
# rebahan : rebah
# ninu : ninu
# ngasih : ngasih
# parasetamol : parasetamol
# beli : beli
# hhhh : hhhh
# dikebutttttt : dikebutttttt
# semisalkan : misal
# merknya : merknya
# sprti : sprti
# goting : goting
# dipakai : pakai
# prog : prog
# brarti : brarti
# dibeli : beli
# hibahnya : hibah
# jayapura : jayapura
# benhur : benhur
# tomi : tom
# mano : mano
# tes : tes
# lacak : lacak
# isolasi : isolasi
# digencarkan : gencar
# temukan : temu
# sebanyaknya : banyak
# menularkan : tular
# pelaskanaan : pelaskanaan
# operasi : operasi
# kemanusiaan : manusia
# bhakti : bhakti
# trida : trida
# sakti : sakti
# tambun : tambun
# kot : kot
# sukarelawan : sukarelawan
# penuh : penuh
# cuti : cuti
# depa : depa
# robot : robot
# fikir : fikir
# penat : penat
# lelah : lelah
# bola : bola
# kursi : kursi
# berserakan : sera
# ditinjau : tinjau
# dikrnkan : dikrnkan
# gada : gada
# sambut : sambut
# menyaksikan : saksi
# kumparan : kumpar
# up : up
# paud : paud
# dikmas : dikmas
# kebon : kebon
# jeruk : jeruk
# usul : usul
# pembagian : bagi
# nutrisi : nutrisi
# hasil : hasil
# nelayan : nelayan
# bergizi : gizi
# penggiat : giat
# ikan : ikan
# tips : tips
# observasi : observasi
# panadol : panadol
# terimakasih : terimakasih
# ketentuan : tentu
# disahkan : sah
# poin : poin
# utamanya : utama
# diperbolehkan : boleh
# bantuan : bantu
# bandel : bandel
# ngeyel : ngeyel
# belajar : ajar
# case : case
# madura : madura
# maaf : maaf
# mengutip : kutip
# pernyataan : nyata
# penceramah : ceramah
# ngawur : ngawur
# menakut : takut
# nakuti : nakuti
# ajaran : ajar
# sesat : sesat
# sribu : sribu
# basa : basa
# sumbul : sumbul
# poskesdes : poskesdes
# perrik : perrik
# mbue : mbue
# pegagan : pegagan
# hilir : hilir
# dairi : dairi
# jun : jun
# penglibatan : libat
# jeli : jeli
# kelantan : lantan
# outreach : outreach
# ayer : ayer
# lanas : lanas
# bertolak : tolak
# telukjambe : telukjambe
# kompol : kompol
# oesman : oesman
# iq : iq
# perumnas : perumnas
# julu : julu
# didirikan : diri
# graha : graha
# usulan : usul
# diselenggarakan : selenggara
# prajurit : prajurit
# yonif : yonif
# mekanis : mekanis
# raider : raider
# bremoro : bremoro
# liputan : liput
# paparkan : papar
# tempatan : tempat
# sedar : dar
# bangli : bangli
# intensifkan : intensif
# bangbang : bangbang
# memperlancar : lancar
# jaringan : jaring
# internet : internet
# registrasi : registrasi
# skrining : skrining
# natuna : natuna
# bekerjasama : bekerjasama
# telkom : telkom
# ranai : ranai
# pemasangan : pasang
# wifi : wifi
# sri : sri
# serindit : serindit
# yos : yos
# sudarso : sudarso
# hitam : hitam
# bunguran : bungur
# pelancong : lancong
# dikarantina : karantina
# tertib : tertib
# favehotel : favehotel
# kuta : kuta
# kartika : kartika
# plaza : plaza
# ibadah : ibadah
# ormas : ormas
# kang : kang
# selidik : selidik
# kebarangkalian : barangkali
# statistik : statistik
# utm : utm
# sebarkan : sebar
# ye : ye
# kenang : kenang
# kelancaran : lancar
# dibangun : bangun
# utara : utara
# gampong : gampong
# seureuke : seureuke
# langkahan : langkah
# mengejar : kejar
# amburadul : amburadul
# salut : salut
# kemaren : kemaren
# protes : protes
# ac : ac
# kasi : kasi
# propam : propam
# murodih : murodih
# covod : covod
# tamgerang : tamgerang
# terjun : terjun
# beliau : beliau
# mengamati : amat
# frame : frame
# ponakannya : ponakan
# emil : emil
# tapiii : tapiii
# priuk : priuk
# paya : paya
# lombang : lombang
# tebing : tebing
# sergei : sergei
# terhindar : hindar
# benda : benda
# smpn : smpn
# post : post
# potretnya : potret
# available : available
# full : full
# mencari : cari
# nunggu : nunggu
# cr : cr
# kecamatannya : camat
# menambah : tambah
# penyanyi : nyanyi
# mendirikan : diri
# menanggulangi : tanggulang
# perekonomian : ekonomi
# kmbali : kmbali
# mpm : mpm
# rent : rent
# diunggah : unggah
# instagram : instagram
# sorotan : sorot
# kewalahan : kewalahan
# calon : calon
# yampun : yampun
# hariiii : hariiii
# seindonesiaa : seindonesiaa
# daku : daku
# mangat : mangat
# je : je
# outlet : outlet
# food : food
# korea : korea
# menghimbau : menghimbau
# dilakukab : dilakukab
# komen : komen
# keliatan : liat
# pandai : pandai
# dipuskesmas : puskesmas
# syahbandar : syahbandar
# pasir : pasir
# serdang : serdang
# bedagai : bedagai
# sisa : sisa
# dana : dana
# segeramenyeluruh : segeramenyeluruh
# kepastian : pasti
# logistik : logistik
# perlkp : perlkp
# asupan : asupan
# diperuntukkan : untuk
# rel : rel
# listrik : listrik
# dosen : dosen
# institut : institut
# teknologi : teknologi
# dirgantara : dirgantara
# adisutjipto : adisutjipto
# feed : feed
# terkini : kini
# mengangkat : angkat
# socmed : socmed
# berbagi : bagi
# dapetinnya : dapetinnya
# kompak : kompak
# dipusatkan : pusat
# aksesnya : akses
# transportnya : transportnya
# murah : murah
# terpecah : pecah
# amankah : aman
# agp : agp
# putih : putih
# ketentuanny : ketentuanny
# momentum : momentum
# sitimulyo : sitimulyo
# piyungan : piyungan
# peruntukan : untuk
# linmas : linmas
# pengurus : urus
# ponpes : ponpes
# icbb : icbb
# kecepatan : cepat
# berpacu : pacu
# berlomba : lomba
# secepatnya : cepat
# aamiin : aamiin
# diarahkan : arah
# wbp : wbp
# tahanan : tahan
# menyelenggarakan : selenggara
# tanggamus : tanggamus
# maron : maron
# loano : loano
# ters : ters
# booster : booster
# siapkan : siap
# perhatikan : perhati
# mencanangkan : canang
# pembelajaran : ajar
# ptm : ptm
# kebal : kebal
# terinfeksi : infeksi
# patuh : patuh
# lockdown : lockdown
# mustahil : mustahil
# penasehat : nasehat
# science : science
# tahniah : tahniah
# spice : spice
# penang : nang
# efisien : efisien
# akses : akses
# melanda : landa
# menerjang : terjang
# terkenal : kenal
# internasional : internasional
# kepedulian : peduli
# patut : patut
# diacungi : acung
# jempol : jempol
# dirikan : diri
# bangga : bangga
# bagikan : bagi
# makanan : makan
# enam : enam
# papua : papua
# hentikan : henti
# aduh : aduh
# herb : herb
# rawasari : rawasari
# cempaka : cempaka
# apartement : apartement
# irwandi : irwandi
# camat : camat
# lurah : lurah
# panti : panti
# waluyo : waluyo
# sawahan : sawah
# rkz : rkz
# monggo : monggo
# yana : yana
# mulyana : mulyana
# didmpingi : didmpingi
# elly : elly
# wasliah : wasliah
# berkerja : kerja
# ende : ende
# tersedia : sedia
# pesta : pesta
# kembang : kembang
# selasa : selasa
# malam : malam
# new : new
# york : york
# amerika : amerika
# serikat : serikat
# pencapaian : capai
# pejabat : jabat
# hompimpah : hompimpah
# genting : genting
# tunda : tunda
# peluang : peluang
# uny : uny
# alergi : alergi
# kambuh : kambuh
# forkompimda : forkompimda
# bor : bor
# rujukan : rujuk
# melonjak : lonjak
# level : level
# nagrak : nagrak
# disiapkan : siap
# ngurusin : ngurusin
# pembukaan : buka
# rame : rame
# book : book
# variannya : varian
# anggap : anggap
# enteng : enteng
# mensolusinya : solusi
# penerbangan : terbang
# dhe : dhe
# trendline : trendline
# growth : growth
# rkp : rkp
# pa : pa
# rapbn : rapbn
# fondasi : fondasi
# pemulihan : pulih
# spending : spending
# outcome : outcome
# ibas : ibas
# dipermudahkan : mudah
# mama : mama
# nnt : nnt
# asih : asih
# dewi : dewi
# sartika : sartika
# mnt : mnt
# kamar : kamar
# dagang : dagang
# menutup : tutup
# shinta : shinta
# wijaya : wijaya
# demand : demand
# stok : stok
# menipis : tip
# sembako : sembako
# lmk : lmk
# membagikan : bagi
# mendorong : dorong
# minat : minat
# paspor : paspor
# diterbitkan : terbit
# stan : stan
# pemeriksaan : periksa
# penyuntikan : sunti
# telekonferensi : telekonferensi
# membludak : membludak
# cilegon : cilegon
# rela : rela
# antre : antre
# subuh : subuh
# bagus : bagus
# lepas : lepas
# serem : rem
# pendatang : datang
# wadidaw : wadidaw
# menghancurkan : hancur
# penampakan : tampak
# detik : detik
# prosesi : prosesi
# jakartakeras : jakartakeras
# babelan : babelan
# puskes : puskes
# rincian : rincian
# gajadi : gajadi
# jaktim : jaktim
# kesel : kesel
# jakut : jakut
# keluhan : keluh
# tangan : tangan
# kaki : kaki
# amin : amin
# curug : curug
# binong : bong
# persiapan : siap
# cilacap : cilacap
# kebut : kebut
# laporan : lapor
# sumpah : sumpah
# ngerti : ngerti
# random : random
# dkk : dkk
# ban : ban
# warganegaranya : warganegaranya
# nggatau : nggatau
# macem : macem
# chill : chill
# amrik : amrik
# santuy : santuy
# eropa : eropa
# spanyol : spanyol
# mencabut : cabut
# pemakaian : pakai
# cempedak : cempedak
# muslih : muslih
# team : team
# jatinegara : jatinegara
# pimpin : pimpin
# akp : akp
# christiandini : christiandini
# hardianti : hardianti
# digerakkan : gerak
# ngaruh : ngaruh
# kematiannya : mati
# volunteer : volunteer
# sayangnya : sayang
# tawarkan : tawar
# hadiah : hadiah
# pengeras : keras
# suara : suara
# rantau : rantau
# pandan : pandan
# gusdianto : gusdianto
# mengajak : ajak
# halal : halal
# jalo : jalo
# muko : muko
# bathin : bathin
# vii : vii
# bungo : bungo
# susu : susu
# beruang : beruang
# istirahat : istirahat
# tekanan : tekan
# darah : darah
# nalar : nalar
# anti : anti
# sains : sains
# tunduk : tunduk
# regulasi : regulasi
# travelling : travelling
# berdiam : diam
# represif : represif
# dialektik : dialektik
# reflektik : reflektik
# cemerlang : cemerlang
# dimata : mata
# diantar : antar
# kanuna : kanuna
# inii : ini
# beb : beb
# penumpang : tumpang
# ribet : ribet
# kayanya : kaya
# poto : poto
# resources : resources
# minerals : minerals
# brms : brms
# langkap : langkap
# anies : anies
# baswedan : baswedan
# potret : potret
# pemuda : pemuda
# gendong : gendong
# kakek : kakek
# bisaa : bisaa
# sbnernya : sbnernya
# kim : kim
# massalnya : massal
# peka : peka
# panutan : panutan
# figur : figur
# kumham : kumham
# suda : suda
# kuduga : duga
# ditanyain : ditanyain
# mantapppp : mantapppp
# kedungwuni : kedungwuni
# pengasuh : asuh
# santri : santri
# huda : huda
# mudahkan : mudah
# pedalaman : dalam
# aq : aq
# matahati : matahati
# freelance : freelance
# manfaatin : manfaatin
# wajib : wajib
# event : event
# nunjukin : nunjukin
# sertifikat : sertifikat
# wkwowkwwkwkwk : wkwowkwwkwkwk
# nonton : nonton
# persib : persib
# ditensi : tensi
# range : range
# ditukur : ditukur
# massif : massif
# wahyudi : wahyudi
# riam : riam
# lantas : lantas
# dibutuhkan : butuh
# mencuci : cuci
# sabun : sabun
# bencana : bencana
# siginifikan : siginifikan
# libur : libur
# idul : idul
# fitri : fitri
# pembentukan : bentuk
# sagita : sagita
# seputaran : putar
# ambu : ambu
# anne : anne
# ratna : ratna
# mustika : mustika
# pelakasanaan : pelakasanaan
# purnawarman : purnawarman
# scan : scan
# qr : qr
# code : code
# gambar : gambar
# universitas : universitas
# uin : uin
# walisongo : walisongo
# poltekkes : poltekkes
# edi : edi
# magelang : magelang
# pendang : dang
# dikaitkeun : dikaitkeun
# duhhh : duhhh
# ig : ig
# generasi : generasi
# semenit : menit
# menggila : gila
# protol : protol
# pola : pola
# makannya : makan
# diperhatikan : perhati
# ditunggu : tunggu
# cmiiw : cmiiw
# persiapkan : siap
# lancar : lancar
# pododadi : pododadi
# vaccine : vaccine
# rektor : rektor
# umpri : umpri
# wilayahnya : wilayah
# 𝗣𝗘𝗟𝗔𝗡 :
# 𝗣𝗘𝗠𝗨𝗟𝗜𝗛𝗔𝗡 :
# 𝗡𝗘𝗚𝗔𝗥𝗔 :
# 𝗦𝗧𝗥𝗔𝗧𝗘𝗚𝗜 :
# 𝗧𝗘𝗥𝗕𝗔𝗜𝗞 :
# tahukah : tahu
# uk : uk
# catat : catat
# tempoh : tempoh
# jangkitan : jangkit
# terbaharu : baharu
# melebihi : lebih
# keliling : keliling
# sekip : sekip
# kadipiro : kadipiro
# informal : informal
# bangkit : bangkit
# seneng : neng
# animo : animo
# bantu : bantu
# reda : reda
# lupa : lupa
# obat : obat
# tameng : tameng
# kuat : kuat
# dibahas : bahas
# militer : militer
# diperbantukan : bantu
# prosedurnya : prosedur
# {'tanjung': 'tanjung', 'balai': 'balai', 'laksanakan': 'laksana', 'vaksinasi': 'vaksinasi', 'dukung': 'dukung', 'program': 'program', 'juta': 'juta', 'lumajang': 'lumajang', 'gelar': 'gelar', 'covid': 'covid', 'massal': 'massal', 'menyebut': 'sebut', 'lonjakan': 'lonjak', 'terkendali': 'kendali', 'lampung': 'lampung', 'menggelar': 'gelar', 'anggota': 'anggota', 'keluarga': 'keluarga', 'rumah': 'rumah', 'sakit': 'sakit', 'jalan': 'jalan', 'pramuka': 'pramuka', 'rajabasa': 'rajabasa', 'kota': 'kota', 'bandar': 'bandar', 'bupati': 'bupati', 'kobar': 'kobar', 'apresiasi': 'apresiasi', 'perusahaan': 'usaha', 'gotong': 'gotong', 'royong': 'royong', 'karyawan': 'karyawan', 'columbia': 'columbia', 'asia': 'asia', 'indonesia': 'indonesia', 'mendukung': 'dukung', 'pengaman': 'kam', 'pelaksanaan': 'laksana', 'warga': 'warga', 'usia': 'usia', 'makamhaji': 'makamhaji', 'bertempat': 'tempat', 'brigadir': 'brigadir', 'ruri': 'ruri', 'setiawan': 'setiawan', 'kartasura': 'kartasura', 'koramil': 'koramil', 'melaksanakan': 'laksana', 'pengamanan': 'aman', 'kegiatan': 'giat', 'kalbar': 'kalbar', 'serius': 'serius', 'lansia': 'lansia', 'salah': 'salah', 'banget': 'banget', 'ujian': 'uji', 'menangisss': 'menangisss', 'silahkan': 'silah', 'simak': 'simak', 'jadwal': 'jadwal', 'ketinggalan': 'tinggal', 'kekebalan': 'kebal', 'tubuh': 'tubuh', 'faktor': 'faktor', 'utama': 'utama', 'hadirnya': 'hadir', 'vaksin': 'vaksin', 'mengusir': 'usir', 'corona': 'corona', 'postingan': 'postingan', 'menyebarkan': 'sebar', 'kabar': 'kabar', 'masyarakat': 'masyarakat', 'berdomisili': 'domisili', 'asli': 'asli', 'dki': 'dki', 'jakarta': 'jakarta', 'dibarengi': 'bareng', 'syarat': 'syarat', 'reposted': 'reposted', 'kemayoran': 'mayor', 'gembira': 'gembira', 'sobat': 'sobat', 'sehat': 'sehat', 'provinsi': 'provinsi', 'resmi': 'resmi', 'membuka': 'buka', 'penyelenggaraan': 'selenggara', 'percepatan': 'cepat', 'ditempat': 'tempat', 'interaksinya': 'interaksi', 'stasiun': 'stasiun', 'bus': 'bus', 'airport': 'airport', 'pelabuhan': 'labuh', 'bogor': 'bogor', 'sukses': 'sukses', 'total': 'total', 'pendaftar': 'daftar', 'online': 'online', 'mencapai': 'capai', 'beneran': 'beneran', 'kuliahnya': 'kuliah', 'tatap': 'tatap', 'muka': 'muka', 'ngambil': 'ngambil', 'mk': 'mk', 'ampu': 'ampu', 'tinjau': 'tinjau', 'tekstil': 'tekstil', 'tracing': 'tracing', 'testing': 'testing', 'diperkuat': 'kuat', 'sukun': 'sukun', 'sukseskan': 'sukses', 'selengkapnya': 'lengkap', 'klik': 'klik', 'tautan': 'taut', 'diinisiasi': 'inisiasi', 'pelaku': 'laku', 'usaha': 'usaha', 'kadin': 'kadin', 'bertujuan': 'tuju', 'mempercepat': 'cepat', 'pemberian': 'beri', 'pekerja': 'kerja', 'pengadaan': 'ada', 'sepenuhnya': 'sepenuh', 'dibiayai': 'biaya', 'dibebankan': 'beban', 'berupaya': 'upaya', 'mewujudkan': 'wujud', '_herd': 'herd', 'immunity_': 'immunity', 'cepat': 'cepat', 'terlaksananya': 'laksana', 'komunal': 'komunal', 'terbentuk': 'bentuk', 'peningkatan': 'tingkat', 'positif': 'positif', 'ditangani': 'tangan', 'strategi': 'strategi', 'menghadapi': 'hadap', 'pandemi': 'pandemi', 'dosis': 'dosis', 'semoga': 'moga', 'penghuni': 'huni', 'apartemen': 'apartemen', 'gading': 'gading', 'mediterania': 'mediterania', 'jenderal': 'jenderal', 'sigit': 'sigit', 'meninjau': 'tinjau', 'pabrik': 'pabrik', 'sukuntex': 'sukuntex', 'pura': 'pura', 'pertambahan': 'tambah', 'tertinggi': 'tinggi', 'positivity': 'positivity', 'rate': 'rate', 'spesimen': 'spesimen', 'meningkat': 'tingkat', 'menurun': 'turun', 'swab': 'swab', 'test': 'test', 'ditingkatkan': 'tingkat', 'mendekati': 'dekat', 'standar': 'standar', 'who': 'who', 'didampingi': 'damping', 'mentri': 'tri', 'kesehatan': 'sehat', 'direktur': 'direktur', 'kai': 'kai', 'disertai': 'serta', 'sebabkan': 'sebab', 'tenda': 'tenda', 'roboh': 'roboh', 'pemprov': 'pemprov', 'gencarkan': 'gencar', 'midji': 'midji', 'ajak': 'ajak', 'daftarkan': 'daftar', 'harapkan': 'harap', 'keras': 'keras', 'secepat': 'cepat', 'cepatnya': 'cepat', 'target': 'target', 'agustus': 'agustus', 'ter ...
# ------------------------
# Pandas Apply:   0%|          | 0/792 [00:00<?, ?it/s]
# 0                    [tanjung, balai, laksana, vaksinasi]
# 1       [dukung, program, juta, vaksinasi, lumajang, g...
# 2                         [sebut, lonjak, covid, kendali]
# 3       [lampung, gelar, vaksinasi, covid, anggota, ke...
# 4       [bupati, kobar, apresiasi, usaha, laksana, vak...
#                               ...
# 998     [grab, luncur, pusat, vaksinasi, ramah, sandan...
# 999     [cegah, sebar, covid, sentra, vaksinasi, kota,...
# 1000    [neng, liat, animo, teman, teman, vaksin, info...
# 1001    [lonjak, covid, izin, vaksin, vaksinasi, mandiri]
# 1002    [bahas, militer, bantu, vaksinasi, tenaga, med...
# Name: tweet_tokens_stemmed, Length: 792, dtype: object
# <ipython-input-15-4a5ae89cc3e7>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tweet_tokens_stemmed'] = df['tweet_tokens_WSW'].swifter.apply(get_stemmed_term)

# %%
df

# %%
df = df.to_csv(r'C:\WPy64-3880\notebooks\AnalisisSentimen_VaksinasiSVM\datasetbismillah\tweetclean.csv', index = None, header=True)

# %% [markdown]
# ## Split Data

# %%
df = pd.read_csv("dataready-lex.csv")

# %%
df
# Out:
#                                                 tweets  sentiment
# 0         ['tanjung', 'balai', 'laksana', 'vaksinasi']        0.0
# 1    ['dukung', 'program', 'juta', 'vaksinasi', 'lu...        1.0
# 2              ['sebut', 'lonjak', 'covid', 'kendali']        1.0
# 3    ['lampung', 'gelar', 'vaksinasi', 'covid', 'an...        0.0
# 4    ['bupati', 'kobar', 'apresiasi', 'usaha', 'lak...        1.0
# ..                                                 ...        ...
# 787  ['grab', 'luncur', 'pusat', 'vaksinasi', 'rama...        1.0
# 788  ['cegah', 'sebar', 'covid', 'sentra', 'vaksina...        1.0
# 789  ['neng', 'liat', 'animo', 'teman', 'teman', 'v...        1.0
# 790  ['lonjak', 'covid', 'izin', 'vaksin', 'vaksina...        0.0
# 791  ['bahas', 'militer', 'bantu', 'vaksinasi', 'te...        1.0
#
# [792 rows x 2 columns]

# %%
from sklearn import model_selection
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(df['tweets'], df['sentiment'], test_size=0.1, random_state=0)

train_df = pd.DataFrame()
train_df['tweets'] = x_train
train_df['sentiment'] = y_train
test_df = pd.DataFrame()
test_df['tweets'] = x_test
test_df['sentiment'] = y_test

# %%
train_df
# Out:
#                                                 tweets  sentiment
# 644  ['personil', 'tebing', 'koramil', 'puskesmas',...        1.0
# 350  ['alam', 'vaksinasi', 'dekat', 'cemput', 'gamp...        1.0
# 733  ['vaksinasi', 'massal', 'stadion', 'cibinong',...        1.0
# 653  ['vaksin', 'covid', 'gratis', 'lokasi', 'vaksi...        1.0
# 504  ['pasongsongan', 'laku', 'cepat', 'vaksinasi',...        1.0
# ..                                                 ...        ...
# 763  ['sagita', 'putar', 'giat', 'ambu', 'bupati', ...        1.0
# 192                       ['syarat', 'bawa', 'lansia']        1.0
# 629  ['menkes', 'pasti', 'tambah', 'ribu', 'dosis',...        1.0
# 559  ['vaksinasi', 'dikebutttttt', 'juta', 'hari', ...        1.0
# 684  ['vaksinasi', 'gratis', 'panti', 'waluyo', 'sa...        1.0
#
# [712 rows x 2 columns]

# %%
test_df
# Out:
#                                                 tweets  sentiment
# 625  ['tinjau', 'vaksinasi', 'massal', 'stadion', '...        1.0
# 142  ['kon', 'tau', 'tha', 'kemudi', 'bluebird', 's...        0.0
# 700  ['moga', 'mudah', 'vaksinasi', 'mama', 'nnt', ...        1.0
# 55   ['vaksin', 'cek', 'rapid', 'antibodi', 'hasil'...        1.0
# 499  ['pemkot', 'jakpus', 'kolaborasi', 'bareng', '...        1.0
# ..                                                 ...        ...
# 669  ['canang', 'ajar', 'tatap', 'muka', 'ptm', 'ba...        1.0
# 375  ['panik', 'gak', 'engga', 'kerabat', 'salah', ...        0.0
# 497  ['udh', 'colong', 'kontak', 'positif', 'pcr', ...        1.0
# 717  ['tinjau', 'vaksinasi', 'massal', 'stadion', '...        1.0
# 253  ['bang', 'rencana', 'ntb', 'vaksinasi', 'masal...        1.0
#
# [80 rows x 2 columns]

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(use_idf=True)
corpus = df['tweets']
x = tfidf_vect.fit(corpus)
x_train_tfidf = x.transform(x_train)
x_test_tfidf = x.transform(x_test)

# %% [raw]
# # print(x_test_tfidf)
#
# # tfidf_vect.get_feature_names()
#
# # x_train_tfidf.todense()
#
# # df = pd.DataFrame(x_train_tfidf.todense().T,
# #                  index=tfidf_vect.get_feature_names(),
# #                  columns=[f'D{i+1}' for i in range(len(x_train))])
# # df
#
# # df = df.to_csv(r'C:\WPy64-3880\notebooks\AnalisisSentimen_VaksinasiSVM\datasetbismillah\tfidf-X_train.csv', header=True)

# %% [markdown]
# ## Perform SVM

# %%
from sklearn import svm

SVM = svm.SVC(kernel='linear')
SVM.fit(x_train_tfidf, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ## Eval Model

# %%
predictions_SVM = SVM.predict(x_test_tfidf)
# print(predictions_SVM)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

confusion_matrix = confusion_matrix(y_test, predictions_SVM)

print('Confusion Matrix : ') 
print(confusion_matrix)
print('\n Report Hasil : ') 
print(classification_report(y_test, predictions_SVM))
# Out:
# Confusion Matrix :
# [[ 5 17]
#  [ 0 58]]
#
#  Report Hasil :
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.23      0.37        22
#          1.0       0.77      1.00      0.87        58
#
#     accuracy                           0.79        80
#    macro avg       0.89      0.61      0.62        80
# weighted avg       0.84      0.79      0.73        80

# %% [markdown]
# ## Visualisasi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix, annot=True, fmt=".0f", ax=ax)
plt.xlabel("prediksi")
plt.ylabel("aktual")
plt.show()

# %%
import matplotlib.pyplot as plt

values = [58, 22]
explode = [0, 0.1]
labels = ['Positif', 'Negatif']
colors = ['blue', 'red']

def make_autopct(values):
    def my_autopct(pct):
        total  = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%({v:d})'.format(p=pct,v=val)
    return my_autopct

plt.pie(values, colors=colors, labels=labels, explode=explode,
      autopct=make_autopct(values), shadow=True, startangle=90)
plt.legend()
plt.title("Hasil Prediksi Sentimen Vaksinasi COVID-19")
plt.show()
